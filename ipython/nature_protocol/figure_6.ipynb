# %% [markdown]
# ### Gene Body Figure
#
# a) Cartoon
# b) High 5' to 3' Relative Coverage for Select Samples

# %%
import sys
sys.path.append('../../src/')
import pandas as pd
import seaborn as sns
import os
# %pylab inline
# %load_ext autoreload
# %autoreload 2
sns.set_context('paper')
sns.set_style("white")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from helpers import *

# %%
qc_dir = os.path.join(local_data, 'nov_24_run', 'qc', 'pratap')

# %%
def load_coverage(fn):
    df = pd.read_table(fn, index_col=0).T
    df.columns = df.columns.map(lambda x: x.split('.')[0][1:])
    df_range = df.max()-df.min()
    normalized_df = (df - df.min())/df_range   
    return normalized_df, df

# %%
fn = os.path.join(qc_dir, 'rseqc-high_expressed.geneBodyCoverage.txt')

# %%
normalized_df, coverage_df = load_coverage(fn)

# %%
import data

# %%
normalized_df = data.paperify_df(normalized_df)

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sample_names, sample_ids = zip(*sorted(get_sample_map().items()))
ax = normalized_df[get_sorted_order()[::-1]].plot(ax=ax, lw=1, color=get_sorted_color_map(), alpha=0.4)
legend = ax.legend(loc=0, )
for label in legend.get_texts():
    label.set_size(8)
labels = ax.set_xticklabels(['','20','40','60','80'])
ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8])
labels = ax.set_yticklabels(['','0.2','0.4','0.6','0.8'])
ax.set_xlabel("Gene Body (5\' -> 3\')")
ax.set_ylabel('Relative Coverage')
ax.grid(alpha=0.4)
#ax.set_title('%s' % gene_name, fontdict={'size':16})
sns.despine()
fig.savefig('../../figures/fig6.png',dpi=300, bbox_inches='tight')

# %%
non_neuronal = mean(normalized_df[[column for column in normalized_df.columns
                                   if column.startswith('Non-neuronal')]], axis=1)
neuronal = mean(normalized_df[[column for column in normalized_df.columns
                                   if column.startswith('Neuronal')]], axis=1)
total = mean(normalized_df[[column for column in normalized_df.columns
                                   if column.startswith('Total')]], axis=1)

# %%
average_df = pd.concat([non_neuronal, neuronal, total], axis=1)
average_df.columns = ['Non-neuronal', 'Neuronal', 'Total RNA']

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
sample_names, sample_ids = zip(*sorted(get_sample_map().items()))
ax = average_df.sort(axis=1).plot(ax=ax, lw=2, color=['Red','Green','Blue'], a)
legend = ax.legend(loc=0, )
for label in legend.get_texts():
    label.set_size(8)
labels = ax.set_xticklabels(['','20','40','60','80'])
ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8])
labels = ax.set_yticklabels(['','0.2','0.4','0.6','0.8'])
ax.set_xlabel("Gene Body (5\' -> 3\')")
ax.set_ylabel('Relative Coverage')
ax.grid(alpha=0.4)
#ax.set_title('%s' % gene_name, fontdict={'size':16})
sns.despine()
fig.savefig('../../figures/fig6_b.png',dpi=300, bbox_inches='tight')

# %%
.plot()
