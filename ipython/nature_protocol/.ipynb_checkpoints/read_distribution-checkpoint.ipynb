# %%
import sys
sys.path.append('../../src/')
import os
import seaborn as sns
import pandas as pd
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from helpers import *

# %%
import data

# %%
mapped_df = data.load_mapped_data()
mapped_df = data.paperify_df(mapped_df.T).T

# %%
mapped_df.sort(ascending=False).plot(kind='barh', stacked=True)

# %% [markdown]
# ### Plot comparing the number of ERCC reads vs Genome reads. Ideally, one would see a linear relationship if the ratio of reads to ERCC concentration was the same for each sample, but as shown below. This does not happen. Maybe the ERCC Spike-in vs ERCC reads linear model will explain this away

# %%
sns.boxplot(mapped_df[['GENOME','ERCC']], color="coral", join_rm=True);
