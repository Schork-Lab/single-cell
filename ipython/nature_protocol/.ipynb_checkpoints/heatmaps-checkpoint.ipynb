# %%
import sys
sys.path.append('../../src/')
import pandas as pd
import seaborn as sns
import os
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from helpers import *
import data

# %%
tpm_df = data.filter_df(data.load_tpms(), genes_only=True)

# %%
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True)
sns.clustermap(tpm_df.corr(method='spearman'),method="average", cmap=cmap)

# %%
low, mid, high = data.get_low_mid_high_genes(tpm_df['Total RNA -100pg-1'], cutoffs=(0.33, 0.95))

# %%
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True)
sns.clustermap(tpm_df.ix[high.index].corr(),method="average", cmap=cmap)

# %%
sns.clustermap(tpm_df.ix[high.index].sort()[:15],method="average", cmap=cmap)
