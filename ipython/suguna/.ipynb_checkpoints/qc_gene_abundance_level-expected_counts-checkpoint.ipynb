# %%
import pandas as pd
import os

# %%
data_dir = '/home/kunal/test'

# %%
# !ls $data_dir
# Out:
# 140728_M01244_0016_000000000-AAGYM		    HCN_RSEM_Tophat-Cufflinks_analysis_data
# Expression in Bulk Nuclei.xlsx			    HCN_RSEM_Tophat-Cufflinks_analysis_data.zip
# Expression in Single Nuclei.xlsx		    HCN_RSEM_TophatCufflinks_analysis_PV_KSR_08123014.xlsx
# HCN_ERCC_analysis-plots_08252014.pptx		    Human cortical nuclei_MISEQ_SK_08252014.pptx
# HCN_RNASEQ_BAM_FILES_08292014			    Reference
# HCN_RNASEQ_BAM_FILES_08292014_EXRACT_KSR	    SampleSheet.csv
# HCN_RNASEQ_BAM_FILES_08292014.zip		    Smart-seq on human brain nuclei-11052014.pptx
# HCN_RNASEQ_READ_COUNT_FILES_11102014		    Thumbs.db
# HCN_RSEM_TOPHAOCUFFLINKS_ANALYSIS_PV_08122014.xlsx

# %%
rsem_dir = os.path.join(data_dir, 'HCN_RSEM_Tophat-Cufflinks_analysis_data','RSEM')

# %%
# !ls $rsem_dir | head
# Out:
# A1-1_S1.genes.results.tsv
# A1-1_S1.isoforms.results.tsv
# A3-1_S16.genes.results.tsv
# A3-1_S16.isoforms.results.tsv
# A4-8_S23.genes.results.tsv
# A4-8_S23.isoforms.results.tsv
# A5-48_S31.genes.results.tsv
# A5-48_S31.isoforms.results.tsv
# A6-RNA-100PG_S35.genes.results.tsv
# A6-RNA-100PG_S35.isoforms.results.tsv

# %%
sample_file = os.path.join(rsem_dir, 'A1-1_S1.genes.results.tsv')

# %% [markdown]
# ### Let's play around with a sample file

# %%
sample_file = os.path.join(rsem_dir, 'A3-1_S16.genes.results.tsv')
sample_df = pd.read_table(sample_file, sep='\t')

# %%
# %pylab inline
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sample_df.TPM.describe()
# Out:
# count     62898.000000
# mean         15.898756
# std        1625.264100
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      336903.560000
# dtype: float64

# %%
sample_df.TPM.hist(range=(1, 500))
# Out:
# /home/kunal/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1279: UserWarning: findfont: Font family [u'Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### From this example sample, it's clear that there is a clear drop-off after about 200 level of TPM.

# %%
from IPython.display import HTML
HTML(sample_df[sample_df.TPM != 0].head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gene_id</th>
#       <th>transcript_id(s)</th>
#       <th>length</th>
#       <th>effective_length</th>
#       <th>expected_count</th>
#       <th>TPM</th>
#       <th>FPKM</th>
#       <th>posterior_mean_count</th>
#       <th>posterior_standard_deviation_of_count</th>
#       <th>pme_TPM</th>
#       <th>pme_FPKM</th>
#       <th>TPM_ci_lower_bound</th>
#       <th>TPM_ci_upper_bound</th>
#       <th>FPKM_ci_lower_bound</th>
#       <th>FPKM_ci_upper_bound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1 </th>
#       <td> ENSG00000000003.10</td>
#       <td> ENST00000373020.4,ENST00000494424.1,ENST000004...</td>
#       <td> 2206</td>
#       <td> 2119.07</td>
#       <td> 2</td>
#       <td>  4.33</td>
#       <td>  6.15</td>
#       <td> 2.00</td>
#       <td> 0.00</td>
#       <td>  4.76</td>
#       <td> 10.52</td>
#       <td>  1.00762</td>
#       <td>  9.50082</td>
#       <td>  2.12068</td>
#       <td>  20.8738</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td>  ENSG00000001084.6</td>
#       <td> ENST00000229416.6,ENST00000504353.1,ENST000005...</td>
#       <td> 2356</td>
#       <td> 2269.07</td>
#       <td> 5</td>
#       <td> 10.10</td>
#       <td> 14.36</td>
#       <td> 5.00</td>
#       <td> 0.00</td>
#       <td> 24.85</td>
#       <td> 54.87</td>
#       <td> 11.23890</td>
#       <td> 40.85280</td>
#       <td> 25.21230</td>
#       <td>  90.5971</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> ENSG00000001630.11</td>
#       <td> ENST00000003100.8,ENST00000422867.1,ENST000004...</td>
#       <td> 3210</td>
#       <td> 3123.07</td>
#       <td> 5</td>
#       <td>  7.34</td>
#       <td> 10.44</td>
#       <td> 4.63</td>
#       <td> 0.65</td>
#       <td> 10.53</td>
#       <td> 23.25</td>
#       <td>  3.21166</td>
#       <td> 19.30550</td>
#       <td>  7.09709</td>
#       <td>  42.6337</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> ENSG00000001631.10</td>
#       <td> ENST00000340022.2,ENST00000394503.2,ENST000003...</td>
#       <td>  546</td>
#       <td>  459.07</td>
#       <td> 1</td>
#       <td>  9.99</td>
#       <td> 14.20</td>
#       <td> 1.00</td>
#       <td> 0.00</td>
#       <td> 44.47</td>
#       <td> 98.20</td>
#       <td> 25.82000</td>
#       <td> 64.97610</td>
#       <td> 57.07120</td>
#       <td> 143.5150</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>  ENSG00000002746.9</td>
#       <td> ENST00000395891.1,ENST00000429529.1,ENST000004...</td>
#       <td>  415</td>
#       <td>  328.07</td>
#       <td> 1</td>
#       <td> 13.98</td>
#       <td> 19.87</td>
#       <td> 1.00</td>
#       <td> 0.05</td>
#       <td> 25.40</td>
#       <td> 56.09</td>
#       <td>  9.93962</td>
#       <td> 42.90030</td>
#       <td> 22.03280</td>
#       <td>  94.8035</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Let's look at this from a bulk sample perspective.

# %%
bulk_sample_file = os.path.join(rsem_dir, 'A5-48_S31.genes.results.tsv')
bulk_sample_df = pd.read_table(bulk_sample_file, sep='\t')

# %%
bulk_sample_df.TPM.describe()
# Out:
# count     62898.000000
# mean         15.898769
# std         911.548258
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      192168.130000
# dtype: float64

# %%
bulk_sample_df.TPM.hist(range=(1, 500))

# %%
HTML(bulk_sample_df[bulk_sample_df.TPM != 0].head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gene_id</th>
#       <th>transcript_id(s)</th>
#       <th>length</th>
#       <th>effective_length</th>
#       <th>expected_count</th>
#       <th>TPM</th>
#       <th>FPKM</th>
#       <th>posterior_mean_count</th>
#       <th>posterior_standard_deviation_of_count</th>
#       <th>pme_TPM</th>
#       <th>pme_FPKM</th>
#       <th>TPM_ci_lower_bound</th>
#       <th>TPM_ci_upper_bound</th>
#       <th>FPKM_ci_lower_bound</th>
#       <th>FPKM_ci_upper_bound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td> ENSG00000000003.10</td>
#       <td> ENST00000373020.4,ENST00000494424.1,ENST000004...</td>
#       <td> 2206.00</td>
#       <td> 2100.69</td>
#       <td> 2</td>
#       <td> 13.69</td>
#       <td> 12.72</td>
#       <td> 2</td>
#       <td> 0</td>
#       <td>  5.28</td>
#       <td> 13.62</td>
#       <td> 1.14141</td>
#       <td> 10.5421</td>
#       <td>  2.9642</td>
#       <td>  27.1620</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>  ENSG00000000419.8</td>
#       <td> ENST00000371582.4,ENST00000371583.5,ENST000003...</td>
#       <td> 1112.48</td>
#       <td> 1007.18</td>
#       <td> 5</td>
#       <td> 71.41</td>
#       <td> 66.34</td>
#       <td> 5</td>
#       <td> 0</td>
#       <td> 18.64</td>
#       <td> 48.02</td>
#       <td> 8.71875</td>
#       <td> 29.6629</td>
#       <td> 22.5198</td>
#       <td>  76.4804</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> ENSG00000000460.12</td>
#       <td> ENST00000286031.6,ENST00000359326.4,ENST000004...</td>
#       <td> 3727.00</td>
#       <td> 3621.69</td>
#       <td> 1</td>
#       <td>  3.97</td>
#       <td>  3.69</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 11.63</td>
#       <td> 29.96</td>
#       <td> 4.22011</td>
#       <td> 19.9684</td>
#       <td> 11.0603</td>
#       <td>  51.6322</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>  ENSG00000001036.8</td>
#       <td> ENST00000002165.5,ENST00000367585.1,ENST000004...</td>
#       <td> 1690.00</td>
#       <td> 1584.69</td>
#       <td> 2</td>
#       <td> 18.15</td>
#       <td> 16.86</td>
#       <td> 2</td>
#       <td> 0</td>
#       <td>  8.16</td>
#       <td> 21.02</td>
#       <td> 2.04072</td>
#       <td> 15.5445</td>
#       <td>  5.7441</td>
#       <td>  40.5428</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>  ENSG00000001084.6</td>
#       <td> ENST00000229416.6,ENST00000504353.1,ENST000005...</td>
#       <td> 3813.00</td>
#       <td> 3707.69</td>
#       <td> 1</td>
#       <td>  3.88</td>
#       <td>  3.60</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 25.55</td>
#       <td> 65.83</td>
#       <td> 9.90219</td>
#       <td> 43.6745</td>
#       <td> 25.7401</td>
#       <td> 112.7840</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Deliverable #1: Genes that are mapped in every single nuclei

# %%
single_nuclei_fns = [os.path.join(rsem_dir,filename)
                    for filename in os.listdir(rsem_dir)
                    if filename.split('-')[1].split('_')[0] == '1' and filename.find('genes') != -1
                    #and not filename.startswith('A1-')]

# %%
def read_nuclei(filename):
    sample_name = os.path.basename(filename).split('.')[0]
    df = pd.read_table(filename, index_col=0)
    df['TPM_'+sample_name] = df['TPM']
    return df[['TPM_'+sample_name]]

# %%
combined_df = pd.concat([read_nuclei(fn)
                         for fn in single_nuclei_fns],
                        axis=1)

# %%
tpm_columns = [column for column in combined_df.columns
               if column.find('TPM') != -1]

# %%
def expressed_in_all(series):
    for column in tpm_columns:
        if series[column] == 0:
            return False
    return True

# %%
combined_df['mean'] = combined_df[tpm_columns].mean(axis=1)
combined_df['std'] = combined_df[tpm_columns].std(axis=1)

# %%
expressed = combined_df.apply(expressed_in_all, axis=1)

# %%
expressed_df = combined_df[expressed]

# %%
expressed_df
# Out:
#                    TPM_A1-1_S1  TPM_A3-1_S16  TPM_B1-1_S2  TPM_B2-1_S9  \
# gene_id
# ENSG00000210082.2       726.29        622.86       498.50       579.16
# ERCC-00002           196194.27     123825.65    109174.18    123394.12
# ERCC-00003             3970.76       7072.23      6135.72      7146.61
# ERCC-00004            58735.04      96433.92    105282.57     99037.38
# ERCC-00009            24773.59      16568.57     14695.72     16207.50
# ERCC-00019              694.17        403.27       570.93       412.42
# ERCC-00022             3159.50       2036.64      1765.86      2001.20
# ERCC-00025              822.69        221.16       317.58       286.80
# ERCC-00162               597.14       603.18        515.86     571.434545
# ERCC-00163                95.21       209.83        186.48     202.011818
# ERCC-00165               583.84      1640.16        584.02     716.795909
# ERCC-00171             30606.45     32323.66      32104.78   30146.107273
#
#                             std
# gene_id
# ENSG00000210082.2   1309.153988
# ERCC-00002         18035.824086
# ERCC-00003           773.032631
# ERCC-00004         11274.186031
# ERCC-00009          2250.303219
# ERCC-00019           133.189125
# ERCC-00022           303.316754
# ERCC-00025           124.936877
# ERCC-00034            43.383037
# ERCC-00035           103.934362
# ERCC-00042           519.812636
# ERCC-00043           479.576284
# ERCC-00044            70.447888
# ERCC-00046          5735.923033
# ERCC-00051            92.602460
# ERCC-00053            43.398950
# ERCC-00059           115.737103
# ERCC-00060           549.777396
# ERCC-00062            69.147393
# ERCC-00071           111.404613
# ERCC-00074         41210.706725
# ERCC-00076           346.946413
# ERCC-00078            91.640949
# ERCC-00079            83.416937
# ERCC-00084            77.747658
# ERCC-00085            54.257924
# ERCC-00092           363.767860
# ERCC-00095           289.361235
# ERCC-00096         13743.852244
# ERCC-00099            71.220778
# ERCC-00108          3086.616717
# ERCC-00111           802.878420
# ERCC-00112           221.490866
# ERCC-00113          5605.344131
# ERCC-00116           485.392511
# ERCC-00126            22.206383
# ERCC-00130          8953.234988
# ERCC-00131           265.049775
# ERCC-00136          1110.721575
# ERCC-00144            85.541585
# ERCC-00145           396.614731
# ERCC-00154            50.776309
# ERCC-00157            49.709934
# ERCC-00160            75.853014
# ERCC-00162           100.889744
# ERCC-00163            83.242655
# ERCC-00165           250.783361
# ERCC-00171          3520.916853
#
# [48 rows x 24 columns]

# %% [markdown]
# ### Only one gene expressed in all. Let's instead just tell the number of samples, it is expressed in.

# %%
def expressed_in_x(series, tpm_columns):
    num_expressed = 0
    for column in tpm_columns:
        if series[column] != 0:
            num_expressed += 1
    return num_expressed

# %%
combined_df['Expressed in x'] = combined_df.apply(expressed_in_x,
                                                  args=[tpm_columns],
                                                  axis=1)

# %%
combined_df.sort('Expressed in x', ascending=False).head()[['mean','std','Expressed in x']]
# Out:
#                     mean          std  Expressed in x
# gene_id
# ERCC-00113  37157.560909  5605.344131              22
# ERCC-00162    571.434545   100.889744              22
# ERCC-00043   2828.523182   479.576284              22
# ERCC-00044    326.621818    70.447888              22
# ERCC-00046  40592.838182  5735.923033              22

# %%
writer = pd.ExcelWriter(os.path.join(data_dir, 'Expression in Single Nuclei.xlsx'))
column_order = ['Expressed in x','mean','std']+tpm_columns
combined_df.sort('Expressed in x', ascending=False)[column_order].to_excel(writer)

# %%
writer.close()

# %% [markdown]
# ### Deliverable #2: Bulk RNA analysis

# %%
bulk_nuclei_fns = [os.path.join(rsem_dir,filename)
                    for filename in os.listdir(rsem_dir)
                    if filename.split('-')[1].split('_')[0] != '1' and filename.find('genes') != -1]

# %%
combined_bulk_df = pd.concat([read_nuclei(fn)
                             for fn in bulk_nuclei_fns],
                             axis=1)

# %%
tpm_bulk_columns = [column for column in combined_bulk_df.columns
                    if column.find('TPM') != -1]

# %%
combined_bulk_df['mean'] = combined_bulk_df[tpm_bulk_columns].mean(axis=1)
combined_bulk_df['std'] = combined_bulk_df[tpm_bulk_columns].std(axis=1)

# %%
combined_bulk_df['Expressed in x'] = combined_bulk_df.apply(expressed_in_x,
                                                            args=[tpm_bulk_columns],
                                                            axis=1)

# %%
combined_bulk_df.sort(['Expressed in x', 'mean'], ascending=False).head()[['mean','std','Expressed in x']]
# Out:
#                      mean           std  Expressed in x
# gene_id
# ERCC-00074  272219.166667  63189.708109              18
# ERCC-00096   95300.201667  26834.566373              18
# ERCC-00002   93648.136111  23965.566556              18
# ERCC-00004   78240.576111  18261.426063              18
# ERCC-00130   72960.702778  20822.541997              18

# %%
writer = pd.ExcelWriter(os.path.join(data_dir, 'Expression in Bulk Nuclei.xlsx'))
column_order = ['Expressed in x','mean','std']+tpm_bulk_columns
combined_bulk_df.sort(['Expressed in x','mean'], ascending=False)[column_order].to_excel(writer)

# %%
writer.close()

# %% [markdown]
# ### Analysis of number of genes expressed

# %%
import seaborn as sns

# %%
fig = plt.figure()
ax = fig.add_subplot(211)
ax = combined_df[combined_df['Expressed in x'] != 0]['Expressed in x'].hist(range=(0,25), ax=ax)
ax.set_title('Number of Single Nuclei Expressing a Gene')
#ax.set_xlabel('Number of Samples')
ax.set_ylabel('Number of Genes')

ax = fig.add_subplot(212)
ax = combined_bulk_df[combined_bulk_df['Expressed in x'] != 0]['Expressed in x'].hist(range=(0,25), ax=ax)
ax.set_title('Number of Bulk Nuclei Expressing a Gene')
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Number of Genes')

fig.tight_layout()

# %% [markdown]
# ### As expected, the bulk samples have more samples that express a large number of genes

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(211)
total_expressed_genes = []
for column in tpm_columns:
    total_expressed_genes.append([column.split('TPM')[1][1:], sum(combined_df[column] != 0)])
ax = pd.DataFrame(total_expressed_genes).set_index(0).plot(kind='barh', width=0.9, ax=ax)
ax.set_xlim([0, 15000])
ax.set_title('Single Nuclei')
#ax.set_xlabel('Number of Samples')
ax.set_ylabel('Sample')

ax = fig.add_subplot(212)
total_expressed_genes = []
for column in tpm_bulk_columns:
    total_expressed_genes.append([column.split('TPM')[1][1:], sum(combined_bulk_df[column] != 0)])
ax = pd.DataFrame(total_expressed_genes).set_index(0).plot(kind='barh', width=0.9, ax=ax)
ax.set_xlim([0, 15000])
ax.set_title('Bulk')
#ax.set_xlabel('Number of Samples')
ax.set_ylabel('Sample')

fig.tight_layout()

# %%
expressed_sample_df = sample_df[sample_df.TPM != 0]

# %%
#Total Reads per Sample
#Total Reads mapped
#Total

# %%
expressed_sample_df.TPM.hist()

# %% [markdown]
# ### Find interesting genes by top expressed, illumina bodymap, and housekeeping genes

# %%
import mygene
mg = mygene.MyGeneInfo()

# %%
def get_common_name(ensemble_id):
    ensemble_id = ensemble_id.split('.')[0]
    try:
        return mg.getgene(ensemble_id, 'name,symbol,refseq')['symbol']
    except AssertionError:
        return ensemble_id
    except:
        try:
            return mg.getgene(ensemble_id, 'name,symbol,refseq')[0]['symbol']
        except:
            return ensemble_id

# %%
combined_df['gene_name'] = combined_df.index.map(get_common_name)

# %%
combined_df['gene_name'].value_counts()

# %%
print 'hello'

# %%
mg.getgenes([x.split('.')[0] for x in combined_df.index], 'name,symbol,refseq', as_dataframe=True)
